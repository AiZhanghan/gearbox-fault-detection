# %%
import pandas as pd

# %%
path = r"E:\data\海装\山西福光宁武牛家岭48MW工程项目\2_[齿轮箱低速轴_垂直径向_齿轮箱内齿圈_水平径向_齿轮箱高速轴_垂直径向].csv"

# %%
# Time,location,freq,signal,RPM,data
read_csv_kw = {
        "header": None, 
        "index_col": 0, 
        "nrows": 10,
        "skiprows": 1, 
#         "delimiter": '\t',
#         "usecols": [0, 1] + [x for x in range(5, 25605)],
#         "converters": {
#             1: lambda x: dic[x], # 处理测点位置(CH -> EN)
#             5: lambda x: x[2:], # 去掉'[
#             25604: lambda x: x[: len(x) - 2], # 去掉]'
#         },
    }

# %%
data = pd.read_csv(path, **read_csv_kw)

# %%
data
# Out:
#                       1      2     3       4         5      6      7      \
# 0
# 20180917020903  齿轮箱低速轴_垂直径向  25600   加速度  1047.7   '[20599  -6485 -17548
# 20181209050741  齿轮箱低速轴_垂直径向  25600   加速度  1047.7   '[14114   6104  16403
# 20181214180740  齿轮箱低速轴_垂直径向  25600   加速度  1047.7   '[10300  24033  33188
# 20180916180739  齿轮箱低速轴_垂直径向  25600   加速度  1047.8  '[-14496  -3052   9918
# 20181209170610  齿轮箱低速轴_垂直径向  25600   加速度  1048.9   '[30518  33951  25558
# 20181213210515  齿轮箱低速轴_垂直径向  25600   加速度  1048.8    '[6104   9537  11444
# 20181201081935  齿轮箱低速轴_垂直径向  25600   加速度  1047.8   '[-4578   4196  22888
# 20181209010448  齿轮箱低速轴_垂直径向  25600   加速度  1048.9   '[-9537  -9537  -1144
# 20180916200616  齿轮箱低速轴_垂直径向  25600   加速度  1051.1   '[-9918  -9537  -8011
# 20180917000946  齿轮箱低速轴_垂直径向  25600   加速度  1050.0    '[5722 -10681  -1526
#
#                 8      9      10     ...  25595  25596  25597  25598  25599  \
# 0                                    ...
# 20180917020903 -13733  -8392  -9918  ...   6866   9537   7629   2289  -2670
# 20181209050741  29373  25558  18311  ...  16785  11444  -4196 -14877  -9918
# 20181214180740  28610  14114   1907  ...  21744  31281  17548  10681  28992
# 20180916180739  22507  32806  33569  ...  12207  13733  16022  11444   1907
# 20181209170610  14114   4196   1907  ...  -2289   6485  17548   9918 -12207
# 20181213210515  16785  25558  25558  ...    381  -2289    763  10300  10681
# 20181201081935  29755   9537 -13733  ...  27084  13733   5341  17166  35858
# 20181209010448   4196   6104   2670  ... -15259  11826  23270  11826   2670
# 20180916200616   4578  13733   5341  ...  35858  45013  47302  36621  27847
# 20180917000946  21744  23270 -10300  ...  -1144   8392  20981  18311   3815
#
#                 25600  25601  25602  25603      25604
# 0
# 20180917020903  -5341      0   8011    381   -14496]'
# 20181209050741   4578  16785   9155 -17166   -23651]'
# 20181214180740  42725  30899  16403  19073    28610]'
# 20180916180739   8011  30136  35477  11826    -4196]'
# 20181209170610 -19836  -1526  17548  10681   -11063]'
# 20181213210515  -2670 -14496 -10300   3815    16022]'
# 20181201081935  32806   9155  -2289  10300    25177]'
# 20181209010448   6866  12970  11826   5722     4196]'
# 20180916200616  29755  31281  20599   1907    -9537]'
# 20180917000946  -2289    763  -1526 -11826   -10300]'
#
# [10 rows x 25604 columns]
