# %%
import pandas as pd

# %%
path = r"E:\data\海装\山西福光宁武牛家岭48MW工程项目\1_[齿轮箱低速轴_垂直径向_齿轮箱内齿圈_水平径向_齿轮箱高速轴_垂直径向].csv"

# %%
# Time,location,freq,signal,RPM,data
read_csv_kw = {
        "header": None, 
        "index_col": 0, 
        "nrows": 10,
        "skiprows": 1, 
#         "delimiter": '\t',
#         "usecols": [0, 1] + [x for x in range(5, 25605)],
#         "converters": {
#             1: lambda x: dic[x], # 处理测点位置(CH -> EN)
#             5: lambda x: x[2:], # 去掉'[
#             25604: lambda x: x[: len(x) - 2], # 去掉]'
#         },
    }

# %%
data = pd.read_csv(path, **read_csv_kw)

# %%
data
# Out:
#                       1      2     3       4         5       6       7      \
# 0
# 20180501000330  齿轮箱低速轴_垂直径向  12800   加速度  1440.1  '[-38147  -27466   70190
# 20180501000330  齿轮箱内齿圈_水平径向   6400   加速度  1440.1   '[12207  120544  -47913
# 20180501000330  齿轮箱高速轴_垂直径向  25600   加速度  1440.1  '[141907  180054  108337
# 20180501010331  齿轮箱低速轴_垂直径向  12800   加速度  1002.4  '[-28992  -19836   -4578
# 20180501010331  齿轮箱内齿圈_水平径向   6400   加速度  1002.4    '[1831    5188   -8850
# 20180501010331  齿轮箱高速轴_垂直径向  25600   加速度  1002.4   '[21362  -22888   15259
# 20180501020330  齿轮箱低速轴_垂直径向  12800   加速度  1058.9   '[24414   85449   25940
# 20180501020330  齿轮箱内齿圈_水平径向   6400   加速度  1058.9   '[11292   21362   89722
# 20180501020330  齿轮箱高速轴_垂直径向  25600   加速度  1058.9  '[-82397 -106812 -120544
# 20180501030333  齿轮箱低速轴_垂直径向  12800   加速度  1058.9  '[-53406   35095  -57983
#
#                  8       9       10     ...   25595   25596   25597   25598  \
# 0                                       ...
# ...
