# %%
import os
import collections
import pandas as pd


import collect_data

# %%
source_path = r"E:\data\海装\CMS\华能三塘湖"
wind_turbines = os.listdir(source_path)

# %%
wind_turbines
# Out:
# ['14',
#  '29',
#  '33',
#  '40',
#  '46',
#  '5',
#  '50',
#  '58',
#  '66',
#  '73',
#  '76',
#  '86',
#  '89',
#  '96']

# %%
wind_turbine = wind_turbines[2]

# %%
files = os.listdir(os.path.join(source_path, wind_turbine))

# %%
files = collect_data.group_by_sensor(files)

# %%
sensors = ["Planet_径向_12800", "Shaft2_径向_25600", "Shaft3_径向_25600"]
files = collect_data.filter_by_sensor(files, sensors)

# %%
files
# Out:
# {'Planet_径向_12800': ['华能三塘湖项目（一期）_D3-33_Planet_径向_12800_加速度g_10.08RPM_20161228173150.csv',
#   '华能三塘湖项目（一期）_D3-33_Planet_径向_12800_加速度g_10.14RPM_20161223182304.csv',
#   '华能三塘湖项目（一期）_D3-33_Planet_径向_12800_加速度g_10.20RPM_20170120084812.csv',
#   '华能三塘湖项目（一期）_D3-33_Planet_径向_12800_加速度g_10.22RPM_20170122042435.csv',
#   '华能三塘湖项目（一期）_D3-33_Planet_径向_12800_加速度g_10.28RPM_20161227154005.csv',
#   '华能三塘湖项目（一期）_D3-33_Planet_径向_12800_加速度g_10.43RPM_20161114131332.csv',
#   '华能三塘湖项目（一期）_D3-33_Planet_径向_12800_加速度g_10.55RPM_20170202112059.csv',
#   '华能三塘湖项目（一期）_D3-33_Planet_径向_12800_加速度g_10.81RPM_20161229135735.csv',
#   '华能三塘湖项目（一期）_D3-33_Planet_径向_12800_加速度g_10.87RPM_20160811003405.csv',
#   '华能三塘湖项目（一期）_D3-33_Planet_径向_12800_加速度g_11.04RPM_20180221090059.csv',
#   '华能三塘湖项目（一期）_D3-33_Planet_径向_12800_加速度g_11.19RPM_20161115013816.csv',
#   '华能三塘湖项目（一期）_D3-33_Planet_径向_12800_加速度g_11.31RPM_20171225081438.csv',
#   '华能三塘湖项目（一期）_D3-33_Planet_径向_12800_加速度g_11.34RPM_20171031220518.csv',
# ...

# %%
sensor =sensors[0]
df = pd.DataFrame(files[sensor])
df.index = pd.to_datetime(df.apply(lambda x: x[0].split("_")[-1][: -4],
    axis=1))
df.sort_index(inplace=True)
df = df["2018": ]

# %%
path = df.values[0][0]

# %%
data = pd.read_csv(os.path.join(source_path, wind_turbine, path), header=None)

# %%
data
# Out:
#      0         1         2         3         4         5         6       \
# 0  0.372933  0.321078  0.264657  0.249311  0.215933  0.127652 -0.017848
#
#      7         8         9       ...    191991    191992    191993    191994  \
# 0 -0.065635 -0.039536 -0.047579  ... -0.452939 -0.468151 -0.332926 -0.148804
#
#      191995    191996    191997    191998    191999  192000
# 0  0.064592  0.169203  0.172895  0.244046  0.311619     NaN
#
# [1 rows x 192001 columns]

# %%
a = pd.DataFrame()

# %%
pd.concat([a, data])

# %%
data.dropna(axis=1, inplace=True)

# %%
data.index = df.iloc[0].index

# %%
data
# Out:
#      0         1         2         3         4         5         6       \
# 0  0.372933  0.321078  0.264657  0.249311  0.215933  0.127652 -0.017848
#
#      7         8         9       ...    191990    191991    191992    191993  \
# 0 -0.065635 -0.039536 -0.047579  ... -0.348894 -0.452939 -0.468151 -0.332926
#
#      191994    191995    191996    191997    191998    191999
# 0 -0.148804  0.064592  0.169203  0.172895  0.244046  0.311619
#
# [1 rows x 192000 columns]

# %%
df.iloc[0]
# Out:
# 0    华能三塘湖项目（一期）_D3-33_Planet_径向_12800_加速度g_15.06RP...
# Name: 2018-01-01 12:13:56, dtype: object

# %%
data.to_csv("test.csv", header=0)

# %%
len(df)
# Out:
# 114

# %%
df
# Out:
#                                                                      0
# 2018-01-01 12:13:56  华能三塘湖项目（一期）_D3-33_Planet_径向_12800_加速度g_15.06RP...
# 2018-01-02 00:14:17  华能三塘湖项目（一期）_D3-33_Planet_径向_12800_加速度g_14.94RP...
# 2018-01-03 06:35:06  华能三塘湖项目（一期）_D3-33_Planet_径向_12800_加速度g_15.00RP...
# 2018-01-04 06:34:27  华能三塘湖项目（一期）_D3-33_Planet_径向_12800_加速度g_15.03RP...
# 2018-01-05 00:20:01  华能三塘湖项目（一期）_D3-33_Planet_径向_12800_加速度g_14.36RP...
# ...                                                                ...
# 2018-04-26 12:14:15  华能三塘湖项目（一期）_D3-33_Planet_径向_12800_加速度g_15.26RP...
# 2018-04-27 06:14:35  华能三塘湖项目（一期）_D3-33_Planet_径向_12800_加速度g_15.12RP...
# 2018-04-28 06:15:49  华能三塘湖项目（一期）_D3-33_Planet_径向_12800_加速度g_15.06RP...
# 2018-04-29 06:16:23  华能三塘湖项目（一期）_D3-33_Planet_径向_12800_加速度g_15.29RP...
# 2018-04-30 00:17:03  华能三塘湖项目（一期）_D3-33_Planet_径向_12800_加速度g_15.03RP...
#
# [114 rows x 1 columns]
