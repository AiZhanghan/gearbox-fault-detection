# %%
# 确认各个测点采样频率

# %%
import pandas as pd

# %%
gearbox_128k_path = r"E:\data\海装\中能建投广东韶关南雄犁牛坪50MW工程项目\001\BqAA-齿轮箱大齿圈行星轮水平3H 128K 加速度信号20180401-20200430.csv"

# %%
gearbox_128k_data = pd.read_csv(gearbox_128k_path, nrows=5)

# %%
gearbox_128k_data
# Out:
#    Unnamed: 0    风机 齿轮箱大齿圈行星轮水平3H               时间  128K 加速度信号  采样时长   采样频率  \
# 0           0  BqAA             BB  20180606183629          18  2560  51200
# 1           1  BqAA             BB  20180607013105          18  2560  51200
# 2           2  BqAA             BB  20180607133035          18  2560  51200
# 3           3  BqAA             BB  20180608173239          18  2560  51200
# 4           4  BqAA             BB  20180608195426          18  2560  51200
#
#    数据类型     单位    数据数目                                                采样值
# 0     1  m/s^2  131072  0.005,0.018,0.004,0.01,0.009,0.006,-0.001,0.00...
# 1     1  m/s^2  131072  0.888,0.908,0.693,0.809,0.629,0.702,1.306,1.00...
# 2     1  m/s^2  131072  1.569,1.391,0.665,0.58,1.165,0.429,-0.183,0.21...
# 3     1  m/s^2  131072  0.046,0.091,0.673,1.322,1.297,1.23,2.487,3.053...
# 4     1  m/s^2  131072  2.166,1.975,1.305,1.185,1.309,0.499,-0.159,-0....

# %%
gearbox_256k_path = r"E:\data\海装\中能建投广东韶关南雄犁牛坪50MW工程项目\001\BqAA-齿轮箱大齿圈行星轮水平3H 256K 加速度信号20180401-20200430.csv"

# %%
gearbox_256k_data = pd.read_csv(path_256k, nrows=5)

# %%
gearbox_256k_data
# Out:
#    Unnamed: 0    风机 齿轮箱大齿圈行星轮水平3H               时间  256K 加速度信号   采样时长  采样频率  \
# 0           0  BqAA             BB  20180606183539          19  51200  5120
# 1           1  BqAA             BB  20180607013037          19  51200  5120
# 2           2  BqAA             BB  20180607132957          19  51200  5120
# 3           3  BqAA             BB  20180608173218          19  51200  5120
# 4           4  BqAA             BB  20180608195349          19  51200  5120
#
#    数据类型     单位    数据数目                                                采样值
# 0     1  m/s^2  262144  0.037,0.036,0.036,0.038,0.036,0.036,0.036,0.03...
# 1     1  m/s^2  262144  -0.321,-0.049,-0.684,-0.52,-0.753,-0.529,0.464...
# 2     1  m/s^2  262144  -0.676,-0.507,-0.066,-0.225,-1.419,1.357,-0.18...
# 3     1  m/s^2  262144  0.942,0.061,-0.15,2.357,0.266,-0.688,-1.08,0.2...
# 4     1  m/s^2  262144  -1.403,-0.918,0.944,0.666,-2.368,0.529,0.146,-...

# %%
low_speed_128k_path = r"E:\data\海装\中能建投广东韶关南雄犁牛坪50MW工程项目\001\BqAA-低速轴垂直4V128K 加速度信号20180401-20200430.csv"

# %%
low_speed_128_data = pd.read_csv(low_speed_128k_path, nrows=5)

# %%
low_speed_128_data
# Out:
#    Unnamed: 0    风机 低速轴垂直4V              时间  128K 加速度信号  采样时长   采样频率  数据类型  \
# 0           0  BqAA      BD  20180606183629          18  2560  51200     1
# 1           1  BqAA      BD  20180607013105          18  2560  51200     1
# 2           2  BqAA      BD  20180607133035          18  2560  51200     1
# 3           3  BqAA      BD  20180608173239          18  2560  51200     1
# 4           4  BqAA      BD  20180608195426          18  2560  51200     1
#
#       单位    数据数目                                                采样值
# 0  m/s^2  131072  -0.001,-0.006,-0.004,-0.002,0.003,0.01,-0.004,...
# 1  m/s^2  131072  -0.329,-0.409,-0.375,-0.198,-0.265,-0.183,-0.1...
# 2  m/s^2  131072  1.855,1.701,0.909,0.669,0.394,0.389,-0.146,-0....
# 3  m/s^2  131072  -2.423,-2.291,-2.352,-2.26,-1.739,-1.282,-0.50...
# 4  m/s^2  131072  -0.89,0.325,1.409,1.66,1.639,1.175,1.38,1.397,...

# %%
low_speed_256k_path = r"E:\data\海装\中能建投广东韶关南雄犁牛坪50MW工程项目\001\BqAA-低速轴垂直4V256K 加速度信号20180401-20200430.csv"

# %%
low_speed_256k_data = pd.read_csv(low_speed_256k_path, nrows=5)

# %%
low_speed_256k_data
# Out:
#    Unnamed: 0    风机 低速轴垂直4V              时间  256K 加速度信号   采样时长  采样频率  数据类型  \
# 0           0  BqAA      BD  20180606183539          19  51200  5120     1
# 1           1  BqAA      BD  20180607013037          19  51200  5120     1
# 2           2  BqAA      BD  20180607132957          19  51200  5120     1
# 3           3  BqAA      BD  20180608173218          19  51200  5120     1
# 4           4  BqAA      BD  20180608195349          19  51200  5120     1
#
#       单位    数据数目                                                采样值
# 0  m/s^2  262144  0.22,0.229,0.225,0.237,0.221,0.225,0.227,0.221...
# 1  m/s^2  262144  -0.606,0.162,0.045,0.465,1.109,0.395,0.147,1.0...
# 2  m/s^2  262144  0.334,-2.253,-1.164,0.657,0.511,0.403,-0.09,0....
# 3  m/s^2  262144  0.154,0.811,0.329,-1.139,-2.046,1.916,1.737,-0...
# 4  m/s^2  262144  1.507,-0.486,-2.96,0.937,-0.602,1.135,2.499,-0...

# %%
high_speed_128k_path = r"E:\data\海装\中能建投广东韶关南雄犁牛坪50MW工程项目\001\BqAA-高速轴垂直5V128K 加速度信号20180401-20200430.csv"

# %%
high_speed_128k_data = pd.read_csv(high_speed_128k_path, nrows=5)

# %%
high_speed_128k_data
# Out:
#    Unnamed: 0    风机 高速轴垂直5V              时间  128K 加速度信号  采样时长   采样频率  数据类型  \
# 0           0  BqAA      BG  20180606183629          18  2560  51200     1
# 1           1  BqAA      BG  20180607013105          18  2560  51200     1
# 2           2  BqAA      BG  20180607133035          18  2560  51200     1
# 3           3  BqAA      BG  20180608173239          18  2560  51200     1
# 4           4  BqAA      BG  20180608195426          18  2560  51200     1
#
#       单位    数据数目                                                采样值
# 0  m/s^2  131072  -0.006,0.001,-0.003,0.014,-0.015,-0.006,0.006,...
# 1  m/s^2  131072  2.768,4.542,4.036,3.177,-0.686,0.231,-1.018,2....
# 2  m/s^2  131072  3.187,2.425,5.517,4.257,5.016,2.25,3.299,2.433...
# 3  m/s^2  131072  -1.617,-2.18,-2.083,-3.509,-3.429,-1.657,0.409...
# 4  m/s^2  131072  -0.178,1.705,2.074,1.722,2.601,5.023,5.451,6.6...

# %%
high_speed_256k_path = r"E:\data\海装\中能建投广东韶关南雄犁牛坪50MW工程项目\001\BqAA-高速轴垂直5V256K 加速度信号20180401-20200430.csv"

# %%
high_speed_256k_data = pd.read_csv(high_speed_256k_path, nrows=5)

# %%
high_speed_256k_data
# Out:
#    Unnamed: 0    风机 高速轴垂直5V              时间  256K 加速度信号   采样时长  采样频率  数据类型  \
# 0           0  BqAA      BG  20180606183539          19  51200  5120     1
# 1           1  BqAA      BG  20180607013037          19  51200  5120     1
# 2           2  BqAA      BG  20180607132957          19  51200  5120     1
# 3           3  BqAA      BG  20180608173218          19  51200  5120     1
# 4           4  BqAA      BG  20180608195349          19  51200  5120     1
#
#       单位    数据数目                                                采样值
# 0  m/s^2  262144  0.192,0.19,0.18,0.187,0.193,0.185,0.191,0.176,...
# 1  m/s^2  262144  -0.64,-2.311,-2.537,-2.589,0.344,3.235,1.406,1...
# 2  m/s^2  262144  -1.417,-3.785,-0.878,2.043,2.024,2.043,2.692,0...
# 3  m/s^2  262144  0.243,-2.79,-1.08,0.034,-4.343,-0.57,2.549,1.5...
# 4  m/s^2  262144  1.213,-5.135,-6.578,5.86,1.668,1.619,4.417,2.3...
